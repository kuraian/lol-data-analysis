# %% [markdown]
# # Exploratory Analysis on the Relationship Between Communication and High Ranked Game Outcomes
#
# It is common knowledge within the high ranking League of Legends playerbase (top 1000 players or GM+ for the purposes of this exercise) that the "bait ping" communication option is used to express frustration at individuals.

# %% [markdown]
# ### Step 1. Collecting and Storing Data
#
# We will use the [Riot Games League of Legends API](https://developer.riotgames.com/docs/lol) to collect and store data. With a development key, we are limited to 20 requests per 1 second and 100 requests per 2 minutes.
#
# Goals:
# - Fetch 100 most recent matches for each player
# - Aggregate all match data into a single file
#
# Limitations:
# - For 200,000 potential matches, we will need about 4000 minutes, or 66 2/3 hours. Due to manually needing to refresh the API development key every 24 hours, let our approach query the API for batches of 50000 matches.
#
# Storage:
# - players.json containing all desired players
# - matches.txt file with all desired match IDs
# - match-data.json file containing match data
#
# Steps:
# - Fetch top 1000 player IDs
# - Fetch list of 100 most recent match IDs for each player
# - Aggregate all desired match IDs into a single file
# - Fetch match data for each ID

# %%
from riotwatcher import LolWatcher, ApiError
from ratelimit import limits, sleep_and_retry
from datetime import date
import json

api_key = 'RGAPI-d116ee48-ca9d-46ae-870a-a1c13708df29'
lol_watcher = LolWatcher(api_key)

@sleep_and_retry
@limits(calls=10, period=12)
def limited_call(func, params):
    return func(*params)

@sleep_and_retry
@limits(calls=10, period=12)
def limited_call_kwargs(func, **kwargs):
    return func(**kwargs)

# %%
challengers = limited_call(lol_watcher.league.challenger_by_queue, ['na1', 'RANKED_SOLO_5x5'])
grandmasters = limited_call(lol_watcher.league.grandmaster_by_queue, ['na1', 'RANKED_SOLO_5x5'])
masters = limited_call(lol_watcher.league.masters_by_queue, ['na1', 'RANKED_SOLO_5x5'])

c_IDs, gm_IDs, m_IDs = ([] for i in range(3))

for entry in challengers['entries']:
    c_IDs.append({'summonerId': entry['summonerId'], 'summonerName': entry['summonerName']})

for entry in grandmasters['entries']:
    gm_IDs.append({'summonerId': entry['summonerId'], 'summonerName': entry['summonerName']})

for entry in masters['entries']:
    m_IDs.append({'summonerId': entry['summonerId'], 'summonerName': entry['summonerName']})

for player in c_IDs + gm_IDs:
    player['puuid'] = limited_call(lol_watcher.summoner.by_id, ['na1', player['summonerId']])['puuid']

# %%
with open('players-' + str(date.today()) + '.json', 'w') as f:
    f.write(json.dumps(c_IDs + gm_IDs))
    f.close()
    
players = []
with open('players-' + str(date.today()) + '.json', 'r') as f:
    for i in f:
        players += json.loads(i)
    f.close()

# %%
matches = []

for player in players:
    matches += limited_call_kwargs(lol_watcher.match.matchlist_by_puuid, **{'region':'na1', 'puuid':player['puuid'], 'queue':420, 'start':0, 'count':100})
    matches += limited_call_kwargs(lol_watcher.match.matchlist_by_puuid, **{'region':'na1', 'puuid':player['puuid'], 'queue':420, 'start':100, 'count':100})
    
matches = [*set(matches)]

with open('players-' + str(date.today()) + '-matches.json', 'w') as f:
    f.write(json.dumps(matches))
    f.close()
    
print(matches)
# Out:
# ['NA1_4772761708', 'NA1_4663780607', 'NA1_4768777558', 'NA1_4688515990', 'NA1_4747483101', 'NA1_4774962363', 'NA1_4723718571', 'NA1_4762036130', 'NA1_4761723295', 'NA1_4746034174', 'NA1_4748588211', 'NA1_4760560908', 'NA1_4703168389', 'NA1_4727753358', 'NA1_4551966941', 'NA1_4777917909', 'NA1_4728749936', 'NA1_4761833051', 'NA1_4772844407', 'NA1_4776271379', 'NA1_4734391879', 'NA1_4711923298', 'NA1_4691542338', 'NA1_4592510659', 'NA1_4623043086', 'NA1_4756835609', 'NA1_4738252195', 'NA1_4699830026', 'NA1_4649735174', 'NA1_4706369721', 'NA1_4739576802', 'NA1_4677589598', 'NA1_4725194377', 'NA1_4613559503', 'NA1_4598022731', 'NA1_4773728000', 'NA1_4700769756', 'NA1_4717500399', 'NA1_4744052980', 'NA1_4645276987', 'NA1_4777372826', 'NA1_4735359067', 'NA1_4735010967', 'NA1_4745998698', 'NA1_4770027059', 'NA1_4771195724', 'NA1_4754676220', 'NA1_4744635873', 'NA1_4777607839', 'NA1_4732127999', 'NA1_4646691628', 'NA1_4755014524', 'NA1_4725808907', 'NA1_4763080249', 'NA1_4451575707', 'NA1_4737130864', 'NA1_4761618151', 'NA1_4722606546', 'NA1_4745867377', 'NA1_4747021433', 'NA1_4735576854', 'NA1_4711680086', 'NA1_4748950921', 'NA1_4732066799', 'NA1_4623787508', 'NA1_4777231217', 'NA1_4756549767', 'NA1_4559249965', 'NA1_4775702699', 'NA1_4758603968', 'NA1_4771990028', 'NA1_4685656368', 'NA1_4738384988', 'NA1_4765537986', 'NA1_4753057311', 'NA1_4756959476', 'NA1_4729121712', 'NA1_4753292490', 'NA1_4689157183', 'NA1_4667157665', 'NA1_4737967781', 'NA1_4727387864', 'NA1_4759520645', 'NA1_4759507002', 'NA1_4735999680', 'NA1_4779288089', 'NA1_4763684528', 'NA1_4744382013', 'NA1_4619215844', 'NA1_4720109895', 'NA1_4766625770', 'NA1_4759847714', 'NA1_4736321461', 'NA1_4732838603', 'NA1_4759790085', 'NA1_4771556626', 'NA1_4712038022', 'NA1_4765364491', 'NA1_4717713982', 'NA1_4772906615', 'NA1_4768071175', 'NA1_4543309134', 'NA1_4760706923', 'NA1_4698987490', 'NA1_4467339183', 'NA1_4760348670', 'NA1_4759881388', 'NA1_4731639816', 'NA1_4748817252', 'NA1_4779314156', 'NA1_4257523114', 'NA1_4718490253', 'NA1_4732791109', 'NA1_4740775562', 'NA1_4758023522', 'NA1_4705637654', 'NA1_4568960377', 'NA1_4686654940', 'NA1_4675705895', 'NA1_4706099958', 'NA1_4701107313', 'NA1_4629858543', 'NA1_4736863737', 'NA1_4768527126', 'NA1_4284023898', 'NA1_4702354774', 'NA1_4772703331', 'NA1_4760771860', 'NA1_4743662089', 'NA1_4741870547', 'NA1_4733644718', 'NA1_4748564701', 'NA1_4648957559', 'NA1_4755694570', 'NA1_4647265332', 'NA1_4757002994', 'NA1_4610967019', 'NA1_4757763887', 'NA1_4773587949', 'NA1_4770312877', 'NA1_4727435186', 'NA1_4744665753', 'NA1_4726954146', 'NA1_4749485350', 'NA1_4759536069', 'NA1_4740442602', 'NA1_4763747157', 'NA1_4739024724', 'NA1_4714806646', 'NA1_4744658740', 'NA1_4752846677', 'NA1_4740001151', 'NA1_4765251074', 'NA1_4771623046', 'NA1_4725755409', 'NA1_4712379392', 'NA1_4763788648', 'NA1_4770480220', 'NA1_4752476997', 'NA1_4713601946', 'NA1_4717587650', 'NA1_4766071801', 'NA1_4761793842', 'NA1_4754997520', 'NA1_4618774187', 'NA1_4737977716', 'NA1_4643050957', 'NA1_4483220326', 'NA1_4754982425', 'NA1_4760171444', 'NA1_4646959951', 'NA1_4774036795', 'NA1_4722268817', 'NA1_4752253748', 'NA1_4746870840', 'NA1_4780235128', 'NA1_4760783948', 'NA1_4688348444', 'NA1_4725140088', 'NA1_4720749514', 'NA1_4772660833', 'NA1_4690324738', 'NA1_4713991643', 'NA1_4705773228', 'NA1_4727520431', 'NA1_4746739874', 'NA1_4713259977', 'NA1_4580931462', 'NA1_4767919505', 'NA1_4744354626', 'NA1_4718472766', 'NA1_4705619273', 'NA1_4530801014', 'NA1_4752662433', 'NA1_4322812736', 'NA1_4762566751', 'NA1_4650581167', 'NA1_4729527459', 'NA1_4743983122', 'NA1_4722711897', 'NA1_4775413568', 'NA1_4740365006', 'NA1_4748180160', 'NA1_4576366874', 'NA1_4525421940', 'NA1_4321534408', 'NA1_4773167654', 'NA1_4718477364', 'NA1_4773834267', 'NA1_4696450908', 'NA1_4767590215', 'NA1_4673940004', 'NA1_4760104895', 'NA1_4767015672', 'NA1_4773256102', 'NA1_4774179925', 'NA1_4575569864', 'NA1_4702160841', 'NA1_4661343109', 'NA1_4772782188', 'NA1_4695642536', 'NA1_4769831462', 'NA ...

# %%
with open('matches.txt', 'w') as f:
    f.write(','.join(matches))
    f.close()

# %%
import csv
with open('matches.txt', 'r') as f:
    reader = csv.reader(f)
    temp = list(reader)[0]
    f.close()
print(temp)
# Out:
# ['NA1_4723671660', 'NA1_4724779809', 'NA1_4738561684', 'NA1_4728481124', 'NA1_4731502643', 'NA1_4740427814', 'NA1_4538482776', 'NA1_4703498984', 'NA1_4617797726', 'NA1_4686852309', 'NA1_4660075240', 'NA1_4700399121', 'NA1_4697611345', 'NA1_4740291000', 'NA1_4023357609', 'NA1_4719341066', 'NA1_4655118173', 'NA1_4708712371', 'NA1_4702209736', 'NA1_4734242497', 'NA1_4740755180', 'NA1_4734100611', 'NA1_4729746162', 'NA1_4644890196', 'NA1_4723994977', 'NA1_4718602984', 'NA1_4457550536', 'NA1_4723774998', 'NA1_4712094645', 'NA1_4723180348', 'NA1_4708879862', 'NA1_4665462273', 'NA1_4727656450', 'NA1_4669369935', 'NA1_4711810972', 'NA1_4645779474', 'NA1_4677147562', 'NA1_4736876007', 'NA1_4733700132', 'NA1_4660543921', 'NA1_4682421648', 'NA1_4679125690', 'NA1_4727701960', 'NA1_4684460824', 'NA1_4730930694', 'NA1_4687568839', 'NA1_4718105171', 'NA1_4724641158', 'NA1_4706943764', 'NA1_4673277054', 'NA1_4692909231', 'NA1_4635631218', 'NA1_4734722873', 'NA1_4611381473', 'NA1_4734676469', 'NA1_4721451393', 'NA1_4710539421', 'NA1_4711626050', 'NA1_4332344896', 'NA1_4711945468', 'NA1_4547508525', 'NA1_4716097058', 'NA1_4717634411', 'NA1_4680010922', 'NA1_4669941234', 'NA1_4731821512', 'NA1_4736399820', 'NA1_4725639458', 'NA1_4668195396', 'NA1_4670221087', 'NA1_4701736979', 'NA1_4721275767', 'NA1_4673192302', 'NA1_4709869122', 'NA1_4701770228', 'NA1_4705284485', 'NA1_4729873010', 'NA1_4721536549', 'NA1_4625879396', 'NA1_4673240055', 'NA1_4735867127', 'NA1_4719273034', 'NA1_4732728116', 'NA1_4740329808', 'NA1_4713312065', 'NA1_4683186417', 'NA1_4715615532', 'NA1_4727415124', 'NA1_4713592431', 'NA1_4641051252', 'NA1_4712462824', 'NA1_4710578990', 'NA1_4688155142', 'NA1_4717487104', 'NA1_4732478431', 'NA1_4674974342', 'NA1_4714719576', 'NA1_4720612514', 'NA1_4647032374', 'NA1_4729993013', 'NA1_4728363896', 'NA1_4719862793', 'NA1_4279018643', 'NA1_4689012682', 'NA1_4689137215', 'NA1_4722493812', 'NA1_4737391883', 'NA1_4718749178', 'NA1_4726344777', 'NA1_4696961585', 'NA1_4736580412', 'NA1_4718170666', 'NA1_4597372651', 'NA1_4707778186', 'NA1_4656178746', 'NA1_4685003192', 'NA1_4734408130', 'NA1_4738748594', 'NA1_4732305162', 'NA1_4691218029', 'NA1_4703396111', 'NA1_4665834329', 'NA1_4667439481', 'NA1_4659650020', 'NA1_4733853846', 'NA1_4636331424', 'NA1_4721728692', 'NA1_4641021449', 'NA1_4638182876', 'NA1_4732413970', 'NA1_4740133449', 'NA1_4694851333', 'NA1_4713569176', 'NA1_4736350070', 'NA1_4718759966', 'NA1_4713187473', 'NA1_4718193246', 'NA1_4707324282', 'NA1_4729406686', 'NA1_4694130866', 'NA1_4710831988', 'NA1_4732604383', 'NA1_4731933337', 'NA1_4734066485', 'NA1_4717609743', 'NA1_4736019819', 'NA1_4696949442', 'NA1_4680415825', 'NA1_4702748169', 'NA1_4709720324', 'NA1_4711535694', 'NA1_4694436324', 'NA1_4729363933', 'NA1_4698900480', 'NA1_4728663997', 'NA1_4650291260', 'NA1_4739508716', 'NA1_4725136232', 'NA1_4702809257', 'NA1_4726397131', 'NA1_4726068641', 'NA1_4731023324', 'NA1_4738571792', 'NA1_4735400412', 'NA1_4725285606', 'NA1_4715098049', 'NA1_4726328290', 'NA1_4730133794', 'NA1_4686267724', 'NA1_4678338270', 'NA1_4712735037', 'NA1_4668385602', 'NA1_4732041694', 'NA1_4655516094', 'NA1_4677314733', 'NA1_4708404260', 'NA1_4741577671', 'NA1_4692727322', 'NA1_4712196407', 'NA1_4736099451', 'NA1_4719382335', 'NA1_4681004656', 'NA1_4723361857', 'NA1_4699301860', 'NA1_4603312519', 'NA1_4715174347', 'NA1_4719368275', 'NA1_4678407962', 'NA1_4731100624', 'NA1_4718059347', 'NA1_4658401689', 'NA1_4693606921', 'NA1_4712189650', 'NA1_4610465141', 'NA1_4692147724', 'NA1_4710156345', 'NA1_4706871753', 'NA1_4734715428', 'NA1_4732543203', 'NA1_4713161003', 'NA1_4736110907', 'NA1_4698818829', 'NA1_4718111581', 'NA1_4607891593', 'NA1_4708541373', 'NA1_4702119222', 'NA1_4736587668', 'NA1_4725946469', 'NA1_4699236497', 'NA1_4725781544', 'NA1_4714582931', 'NA1_4670245450', 'NA1_4717916136', 'NA1_4704342495', 'NA1_4735432916', 'NA1_4712704505', 'NA1_4671501191', 'NA1_4698355555', 'NA1_4257837770', 'NA1_4590068953', 'NA1_4707499709', 'NA1_4738034842', 'NA ...

# %%
print(players)
# Out:
# [{'summonerId': 'nJHkwhwfitnJW5gFPq_-n4Qv8HuewB1Vy9vyz9uc3atI414', 'summonerName': 'YMGYMG', 'puuid': 'qTJAi6Q-mtWOE_9x1eoQVpgpHGCKm5siGUP9KVPjHCUOmFcyOW7fF8UceXMP2lWgQR3WXMN1a_ut-g'}, {'summonerId': '-rDUhN-F24e7vfUkWCBt16wZUsJjHgn2R6nFMh9XsGp-Zl9u', 'summonerName': 'ItzNotYoru', 'puuid': 'uFtWzb-irfpFMMdvB1ncTwvgcTJpyR9fVUqjcrl1MGTMt9vcXTlFf38WR-tqAdB7GWVLAwSB0PDZvg'}, {'summonerId': 'dB7H89LLv62F8ZYBY0WhQ2CR0gH-ai07aWeU6XgAwfXJHz8', 'summonerName': 'Souldier', 'puuid': 'tWyemvlRjZkS-wvpZaOHTlQM6EJlYQGz5VUeeulN6iY411eJoYcEYBIyIbGrFXu-vt9uUWYBtwW8_A'}, {'summonerId': 'wFaw8HVe5UHxB_hPC2djLbKmua_8wPhNSQtww0tU_JBkzWc', 'summonerName': 'NinjaSenpai', 'puuid': 'qGjWIqw_XFYSo303de_zyvzOFJy88Ft8Q6heCrv1XMjAT83mzgM4xNVigRt5_QUZ7Q3p4xIcifHfxA'}, {'summonerId': 'a4bjAr_YKVjg6vkr31feSzlH4hpi7MvqPYb0uxggbFTjtMA', 'summonerName': 'Neøø', 'puuid': 'sesBYj0s2vIylLGQUPhLf-04JpdsGUM_zjPGG_WFe8wMKv9nt8LkOA5QgdLHwqUl3hBB_BuflYjL1g'}, {'summonerId': 'eekLovPY69x75OJ-ToQJ6ivdG5f2TCw3fpNMpFco4kbWUEw', 'summonerName': 'Stabsie', 'puuid': 'NDkLopw-efwxazQX2jELXQX0cHqZe3rcY9BMITx8NCa0SXixISwC3T1anSF4ilwcP5sob-9yb83PuA'}, {'summonerId': 'BqFr3TTi12qHvya8Q5VPO2_fAfLBmHVyjfc35_eJOKadI_Ud', 'summonerName': 'luvbaka', 'puuid': '4kNrcAF6MaM1jVWV6NpJGOlpwYloabErHcRohWSpAHNZsqpxXmA7Iv4T6eblLkiY_fJ95pMzGnzIoQ'}, {'summonerId': 'K96m4DNTJ10m2rg6iaotavLz2Xt4fUMYAoft_IK3kzvuTMemU2g0QiVlWw', 'summonerName': 'Fenickz', 'puuid': 'Z-6AoAPU7Y5ALWlWMI2ZdQeEEvclfyaKoLnGcQ1OS9Sk3ITieycZiVFqZeY5z2B3GjjgHc43j0gH6A'}, {'summonerId': 'xFgmjqhfWRATL8_TQTlZqoOMWJOmSBSaxBENoJ79nb9wyO4', 'summonerName': 'RoseThorn', 'puuid': 'cKu47g4H27evJUGSD0k03aaNiYNXyMNoB8BxTcY4-KvF-HOVt0UXgQjyGKGtNYaEyPggvP8MYasJ8w'}, {'summonerId': 'GgPMkwfByks0pXvdHW4t1XWKatdz9TlQEDgGel4HHz3Nl3c', 'summonerName': '100 Tenacity', 'puuid': '7BqwQS4mjv1RQnDpkOSGwgvmMQWsPHGX8zJuLhBMYg_RG4IemTQqUQxZsUroRS_4h_ZXRamC4vQEXQ'}, {'summonerId': 'gUOa5UWig82FaDhhIg-Uc7ptImSLrUfkmeYA6QWsZSW0jWk', 'summonerName': 'Abzorb', 'puuid': 'C1h-9vYK1BYgJqpVJRRmVwCg37GMgSZ465qxFi9MIMLx2fF2QV9rkPBHjBFuKyurrQ-Pf2nZ_l11ZQ'}, {'summonerId': 'C6dmgG9GsS7S1ZQY9ahrOX_gttjMJNT9d66RyzDupSluU1A', 'summonerName': 'Airflash', 'puuid': 'fDbaav8kgtKsaAFRbQGXx3BOYQtaVxYTw6J3jA7QZQ20zpU2EhcxJpHYnyamKYvpJSbiXPas03ec_Q'}, {'summonerId': 'EeKXUtLyMJbFyH6tHWbX9lTTmZ2NH4ib0ggH3rXnmBmO7Xw', 'summonerName': 'Wocaoo', 'puuid': 'PpbVN8M-zeMg52nZlVzcQ1bnzZjiclJ3MntvbSMQJ0UE2nA0S6nSS2fqTtXDlKVNEejlIOi5kp2cQA'}, {'summonerId': 'sCYtORgyGjTckaQkEn4abtJjmt-My4ZQykJKsf1HzCTBcNY', 'summonerName': 'Cupic', 'puuid': 'S9bV0KIrir4LrDn4Dqfrn0Rft-UUGabGDAqIiDdlVUc49yjHTbzRpsBKDSQgtDzm1rFgFc1FizGWWA'}, {'summonerId': 'mEnl4rdlTcfHroyZb2pDKxjj2U_l7SMo53tpmSE7uI0AZco', 'summonerName': 'Doubtfull', 'puuid': 'Gib0BNj0aFcWlvz-wPysCpi8pKEr1-STfpHtmjVMF69ezwIolXJEhmevA5CCtQ1BGExK9ytBhxT3kg'}, {'summonerId': 'snL2soCnp3sxcUyf5wqcKc7Klez67lgMS6ayNEhi74WD_M8', 'summonerName': 'wx Mjm978244659', 'puuid': 'hr5_gpU7EtW6RBC7g0hqyLs0qV36baKyDxz4856SPT4yxeo3PgVSj3nRCU9-YE6akdx-uNUJwAxWTQ'}, {'summonerId': 'cYbN6x5eVLbErDo6U-5xPTYrYwkEp9RSnsdTaVp1MgdhyUFM', 'summonerName': 'absolutefocus9', 'puuid': 'L7-H7HypPGY4RHsH9ozGCiD0Si9dA50cPEzp1QAYaxzDfEhF9I_RNJbrHcH7tmkMR7oAYWdntw7W1w'}, {'summonerId': 'Et6CqNLPmvY5JF_8txD6RdkxaCdfFm-t_l3wJSoop5YqQl0', 'summonerName': 'Xuuka', 'puuid': 'ZrQxKIN1lH2lxDXQFZl7-4BTRO9MlhAOUfotltPyerNsTnSKDSuSaPeKtA2KfmKUq_jqSgyeBxCP6g'}, {'summonerId': 'DZEb5SVay9PIvDMG_UevAfPO7OBq1sSLX-ZmCWILl5AkelfGEaQ5NEHuSA', 'summonerName': 'Proud Knight', 'puuid': 'tX4k-ltFss0kR2KoYdN14EWU2n5fe6mTmlzlNKNtr0z7GigJR8buPOvZGGu8bQNNmKr5FforObGL8A'}, {'summonerId': '4eUi7rUC7NfS69bMWFkKJZPltQRg3slpXZXP-xN1tpFtwo4', 'summonerName': 'Windoges', 'puuid': 'NRRr6gnbb-XqiPqIIMdoM7JqAJOXMGAeCMuo81y7mrr2WviaSY65zqKqCEkNzhdCKArFIGoFdlpMow'}, {'summonerId': 'mGkLffAL75dqu586ZwWIptf5Hb_OxHOWvYo21Yl53VRhuEw', 'summonerName': 'BriarFootSmeller', 'puuid': '9inImB2kH-Qp9uLWOUyTAXtHvg2nym1iBIXGVkVHv70okVChhcy90lvvyOja75xjsDGmQY4055F_OA'}, {'summonerId': 'p51-bYYUVgLWP4xwj_MkrQj9R4YGj0GWkem ...

# %%
print(len(matches))
# Out:
# 93411

# %%
matches1 = matches[2360:49999]
matches2 = matches[50000:]

for match in matches1:
    try:
        data = lol_watcher.match.by_id('na1', match)
        with open('./data/' + match + '.json', 'w') as f:
            f.write(json.dumps(data))
    except:
        pass
